# %% [markdown]
# <a href="https://colab.research.google.com/github/yashvardhan-rustedlegend/Twitter-Sentimental-Analysis-Project/blob/main/Twitter_Sentimental_Ananlysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tweepy
# all 4 authentication keys to access twitter API
# to connect as OAth handler or jump serever / revers proxy server
consumer_key = "8AO6OU5ubyi4XO47b1C7Sjdlz"
consumer_sec = "FS1usPrfPolvjLXbwGka5N8TWkOZhUsdxGmmTwuO016koesUSt"

# from proxy server we need to connect
access_token = "1151573806680592384-OUFeUtpsRFZM6jQxl1AG99NEjlY0Kt"
access_token_sec = "KKHmkHkDGVaDof8XK4fKKI52DmNl4vZlaXnx85WRfd4Lr"

# %%
# connected to jump server of twitter
auth = tweepy.OAuthHandler(consumer_key,consumer_sec)

# %%
# now we can connect from jump server to web server to twitter
auth.set_access_token(access_token,access_token_sec)

# %%
#now we can connect to API Strong server of twitter
api_connect=tweepy.API(auth)

# %%
tweet_data = api_connect.search('avengers',count=100)

# %%
for tweet in tweet_data:
  print(tweet.text)
# Out:
# RT @FilmUpdates: #SpiderManNoWayHome is expected to debut with an estimated $242M–$247.5M+ over three days, which would make it the fourth…
# @ItsBrimbram @THawk42017647 @BobDuckNWeave @TypicalTurtlez @PlayAvengers @DotPone I mean, saying that the swinging… https://t.co/7numCStVx4
# RT @RobertMBall: Th’Avengers https://t.co/1uSjEnGjc2
# Travis Smith
# Acculturated: Superhero Ethics : 10 Comic Book Heroes; 10 Ways to Save the World;
# $14.95… https://t.co/I8JlPoKtfX
# #SpiderManNoWayHome signe le 2e meilleur démarrage US de tous les temps pour son premier jour d'exploitation.
# Aux… https://t.co/U9S58RDv0b
# RT @GiteshPandya: UPDATE: Top 5 Opening Days of All-Time:
#
# $157.5M #AvengersEndgame
# $121.5M #SpiderManNoWayHome
# $119.1M #StarWars Force A…
# RT @FilmUpdates: #SpiderManNoWayHome had the second best opening day in the history of the domestic box office with $121.5M (including $50M…
# RT @joshieyamaguchi: na we need the avengers
# RT @VladZdor: Hawkeye family 🏹🏹🏹
# ...

# %%
from textblob import TextBlob
import matplotlib.pyplot as plt

# %%
pos = 0
neg = 0
neu = 0

for tweet in tweet_data:
  analysis = TextBlob(tweet.text)
  print(analysis.sentiment)
  if analysis.sentiment.polarity > 0:
    print("Positive")
    pos = pos+1
  elif   analysis.sentiment.polarity < 0:
    print("Negative")
    neg = neg+1
  else:
    print("Neutral")
    neu = neu+1


#Plotting graph
plt.xlabel("tags")
plt.ylabel("Polarity")
plt.pie([pos,neg,neu],labels=['pos','neg','neu'],autopct="%1.1f%%")
plt.show()
# Out:
# Sentiment(polarity=-0.1, subjectivity=0.4)
# Negative
# Sentiment(polarity=-0.3125, subjectivity=0.6875)
# Negative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.25, subjectivity=0.5)
# Positive
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.5, subjectivity=0.5)
# Positive
# Sentiment(polarity=0.3333333333333333, subjectivity=0.13333333333333333)
# Positive
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.2388888888888889, subjectivity=0.4527777777777778)
# Positive
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.5, subjectivity=0.5)
# Positive
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=3.700743415417188e-17, subjectivity=0.5222222222222223)
# Positive
# Sentiment(polarity=0.5, subjectivity=0.5)
# Positive
# Sentiment(polarity=-0.14999999999999997, subjectivity=0.875)
# Negative
# ...
